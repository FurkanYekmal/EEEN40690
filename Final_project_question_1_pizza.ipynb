# %%
import numpy as np
import matplotlib.pyplot as plt
import math
import pandas as pd

df = pd.read_csv(r"D:\Modules_UCD\EEEN40690\Final project\Pizza.csv")

df.head()
# Out:
#   brand     id   mois   prot    fat   ash  sodium  carb   cal
# 0     A  14069  27.82  21.43  44.87  5.11    1.77  0.77  4.93
# 1     A  14053  28.49  21.26  43.89  5.34    1.79  1.02  4.84
# 2     A  14025  28.35  19.99  45.78  5.08    1.63  0.80  4.95
# 3     A  14016  30.55  20.15  43.13  4.79    1.61  1.38  4.74
# 4     A  14005  30.49  21.28  41.65  4.82    1.64  1.76  4.67

# %%
df.columns
# Out:
# Index(['brand', 'id', 'mois', 'prot', 'fat', 'ash', 'sodium', 'carb', 'cal'], dtype='object')

# %%
df.head()
# Out:
#    brand     id   mois   prot    fat   ash  sodium  carb   cal
# 0      1  14069  27.82  21.43  44.87  5.11    1.77  0.77  4.93
# 1      1  14053  28.49  21.26  43.89  5.34    1.79  1.02  4.84
# 2      1  14025  28.35  19.99  45.78  5.08    1.63  0.80  4.95
# 3      1  14016  30.55  20.15  43.13  4.79    1.61  1.38  4.74
# 4      1  14005  30.49  21.28  41.65  4.82    1.64  1.76  4.67

# %%
df.describe()
# Out:
#             brand            id        mois        prot         fat  \
# count  300.000000    300.000000  300.000000  300.000000  300.000000
# mean     5.560000  20841.040000   40.903067   13.373567   20.229533
# std      2.889214   6962.917222    9.552987    6.434392    8.975658
# min      1.000000  14003.000000   25.000000    6.980000    4.380000
# 25%      3.000000  14093.750000   30.902500    8.060000   14.770000
# 50%      6.000000  24020.500000   43.300000   10.440000   17.135000
# 75%      8.000000  24110.250000   49.115000   20.022500   21.435000
# max     10.000000  34045.000000   57.220000   28.480000   47.200000
#
#               ash      sodium        carb         cal
# count  300.000000  300.000000  300.000000  300.000000
# mean     2.633233    0.669400   22.864767    3.271000
# std      1.269724    0.370358   18.029722    0.620034
# min      1.170000    0.250000    0.510000    2.180000
# 25%      1.450000    0.450000    3.467500    2.910000
# 50%      2.225000    0.490000   23.245000    3.215000
# 75%      3.592500    0.702500   41.337500    3.520000
# max      5.430000    1.790000   48.640000    5.080000

# %%
print(df)
# Out:
#      brand     id   mois   prot    fat   ash  sodium   carb   cal
# 0        1  14069  27.82  21.43  44.87  5.11    1.77   0.77  4.93
# 1        1  14053  28.49  21.26  43.89  5.34    1.79   1.02  4.84
# 2        1  14025  28.35  19.99  45.78  5.08    1.63   0.80  4.95
# 3        1  14016  30.55  20.15  43.13  4.79    1.61   1.38  4.74
# 4        1  14005  30.49  21.28  41.65  4.82    1.64   1.76  4.67
# ..     ...    ...    ...    ...    ...   ...     ...    ...   ...
# 295     10  34044  44.91  11.07  17.00  2.49    0.66  25.36  2.91
# 296     10  24069  43.15  11.79  18.46  2.43    0.67  24.17  3.10
# 297     10  34039  44.55  11.01  16.03  2.43    0.64  25.98  2.92
# 298     10  14044  47.60  10.43  15.18  2.32    0.56  24.47  2.76
# 299     10  14045  46.84   9.91  15.50  2.27    0.57  25.48  2.81
#
# [300 rows x 9 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   brand   300 non-null    int64
#  1   id      300 non-null    int64
#  2   mois    300 non-null    float64
#  3   prot    300 non-null    float64
#  4   fat     300 non-null    float64
#  5   ash     300 non-null    float64
#  6   sodium  300 non-null    float64
#  7   carb    300 non-null    float64
#  8   cal     300 non-null    float64
# dtypes: float64(7), int64(2)
# memory usage: 21.2 KB

# %%
df.isnull().sum()
# Out:
# brand     0
# id        0
# mois      0
# prot      0
# fat       0
# ash       0
# sodium    0
# carb      0
# cal       0
# dtype: int64

# %%
import seaborn as sns

# %%
X = df.drop('brand', axis = 1)
y = df['brand']

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=0)

ss = StandardScaler()

X_train = ss.fit_transform(X_train)
X_test = ss.transform(X_test)

# %%
from sklearn.svm import SVC

# %%
SVMlinear=SVC(kernel='linear', random_state = 0)
SVMpoly=SVC(kernel='poly', random_state=0)
SVMrbf=SVC(kernel='rbf', random_state=0)
SVMsigmoid=SVC(kernel='sigmoid', random_state=0)

# %%
SVMlinear.fit(X_train,y_train)
SVMpoly.fit(X_train,y_train)
SVMrbf.fit(X_train,y_train)
SVMsigmoid.fit(X_train,y_train)
# Out:
# SVC(kernel='sigmoid', random_state=0)

# %%
SVMlinear_pred = SVMlinear.predict(X_test)
SVMpoly_pred = SVMpoly.predict(X_test)
SVMrbf_pred = SVMrbf.predict(X_test)
SVMsigmoid_pred = SVMsigmoid.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

# %%
Accuracy_of_SVMlinear = accuracy_score(y_test, SVMlinear_pred)
print(Accuracy_of_SVMlinear)
Accuracy_of_SVMpoly = accuracy_score(y_test, SVMpoly_pred)
print(Accuracy_of_SVMpoly)
Accuracy_of_SVMrbf = accuracy_score(y_test, SVMrbf_pred)
print(Accuracy_of_SVMrbf)
Accuracy_of_SVMsigmoid = accuracy_score(y_test, SVMsigmoid_pred)
print(Accuracy_of_SVMsigmoid)
# Out:
# 0.7222222222222222
# 0.6666666666666666
# 0.6888888888888889
# 0.7

# %%
df.corr()
# Out:
#            brand        id      mois      prot       fat       ash    sodium  \
# brand   1.000000  0.137863  0.054345 -0.642819 -0.747133 -0.704272 -0.651801
# id      0.137863  1.000000  0.032595 -0.076485 -0.004860 -0.034072 -0.015156
# mois    0.054345  0.032595  1.000000  0.360248 -0.171318  0.265556 -0.102279
# prot   -0.642819 -0.076485  0.360248  1.000000  0.498002  0.823844  0.429130
# fat    -0.747133 -0.004860 -0.171318  0.498002  1.000000  0.791634  0.933325
# ash    -0.704272 -0.034072  0.265556  0.823844  0.791634  1.000000  0.808122
# sodium -0.651801 -0.015156 -0.102279  0.429130  0.933325  0.808122  1.000000
# carb    0.622186  0.014966 -0.591802 -0.853542 -0.640238 -0.898988 -0.620176
# cal    -0.517628 -0.021209 -0.764441  0.070258  0.764567  0.326468  0.671958
#
#             carb       cal
# brand   0.622186 -0.517628
# id      0.014966 -0.021209
# mois   -0.591802 -0.764441
# prot   -0.853542  0.070258
# fat    -0.640238  0.764567
# ash    -0.898988  0.326468
# sodium -0.620176  0.671958
# carb    1.000000 -0.023485
# cal    -0.023485  1.000000

# %%
df_sample = df.sample(n=100)
plt.figure(figsize=(12, 8))
sns.heatmap(df_sample.corr(), cmap='GnBu', linewidths=0.2, vmin=-1, vmax=1, annot=True, fmt = '0.2')
plt.show()

# %%
df.corr()
plt.figure(figsize=(12, 8))
sns.heatmap(df.corr(), cmap='GnBu', linewidths=0.2, vmin=-1, vmax=1, annot=True, fmt = '0.2')
plt.show()

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
print("\n\nClassification Report\n ",classification_report(y_test,SVMlinear_pred))


con_mat = confusion_matrix(y_test,SVMlinear_pred)
sns.heatmap(con_mat, annot=True, square=True)
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('Confusion Matrix')
# Out:
# Classification Report
#                 precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00         9
#            2       1.00      1.00      1.00         7
#            3       0.88      1.00      0.93         7
#            4       1.00      0.90      0.95        10
#            5       0.27      0.67      0.39         9
#            6       0.80      0.50      0.62         8
#            7       0.50      0.67      0.57         6
#            8       0.50      0.17      0.25        18
#            9       1.00      1.00      1.00         7
#           10       1.00      1.00      1.00         9
#
#     accuracy                           0.72        90
#    macro avg       0.79      0.79      0.77        90
# weighted avg       0.77      0.72      0.71        90
# Text(0.5, 1.0, 'Confusion Matrix')

# %%
print("\n\nClassification Report\n ",classification_report(y_test,SVMrbf_pred))



con_mat = confusion_matrix(y_test,SVMrbf_pred)
sns.heatmap(con_mat, annot=True, square=True)
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('Confusion Matrix')
# Out:
# Classification Report
#                 precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00         9
#            2       1.00      1.00      1.00         7
#            3       0.88      1.00      0.93         7
#            4       1.00      0.90      0.95        10
#            5       0.32      1.00      0.49         9
#            6       0.00      0.00      0.00         8
#            7       0.38      0.83      0.53         6
#            8       0.00      0.00      0.00        18
#            9       1.00      1.00      1.00         7
#           10       1.00      1.00      1.00         9
#
#     accuracy                           0.69        90
#    macro avg       0.66      0.77      0.69        90
# weighted avg       0.59      0.69      0.62        90
# C:\Users\Furka\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Furka\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Furka\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Text(0.5, 1.0, 'Confusion Matrix')

# %%
print("\n\nClassification Report\n ",classification_report(y_test,SVMpoly_pred))



con_mat = confusion_matrix(y_test,SVMpoly_pred)
sns.heatmap(con_mat, annot=True, square=True)
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('Confusion Matrix')
# Out:
# Classification Report
#                 precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00         9
#            2       1.00      1.00      1.00         7
#            3       0.88      1.00      0.93         7
#            4       1.00      0.90      0.95        10
#            5       0.25      0.67      0.36         9
#            6       0.00      0.00      0.00         8
#            7       0.38      0.83      0.53         6
#            8       0.33      0.06      0.10        18
#            9       1.00      1.00      1.00         7
#           10       0.90      1.00      0.95         9
#
#     accuracy                           0.67        90
#    macro avg       0.67      0.75      0.68        90
# weighted avg       0.64      0.67      0.62        90
# C:\Users\Furka\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Furka\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Furka\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Text(0.5, 1.0, 'Confusion Matrix')

# %%
print("\n\nClassification Report\n ",classification_report(y_test,SVMsigmoid_pred))



con_mat = confusion_matrix(y_test,SVMsigmoid_pred)
sns.heatmap(con_mat, annot=True, square=True)
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('Confusion Matrix')
# Out:
# Classification Report
#                 precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00         9
#            2       1.00      1.00      1.00         7
#            3       0.88      1.00      0.93         7
#            4       1.00      0.90      0.95        10
#            5       0.35      1.00      0.51         9
#            6       0.00      0.00      0.00         8
#            7       0.40      1.00      0.57         6
#            8       0.00      0.00      0.00        18
#            9       1.00      1.00      1.00         7
#           10       1.00      1.00      1.00         9
#
#     accuracy                           0.70        90
#    macro avg       0.66      0.79      0.70        90
# weighted avg       0.60      0.70      0.62        90
# C:\Users\Furka\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Furka\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Furka\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Text(0.5, 1.0, 'Confusion Matrix')
