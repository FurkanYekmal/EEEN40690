# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report,confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# %%
training_data = pd.read_csv("D:\Modules_UCD\EEEN40690\Final project\Wine_train.csv")
training_data = training_data.drop('id',axis=1)
training_data
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0      13.05        0.40  2.40              21.68      71.79           2.33
# 1      13.01        3.66  2.21              16.53      98.87           2.46
# 2      13.13        1.14  2.32              18.75     108.51           2.63
# 3      12.06        1.41  2.04              16.58      73.52           0.84
# 4      12.35        1.14  1.91              19.52      77.65           2.09
# ..       ...         ...   ...                ...        ...            ...
# 529    13.34        1.48  2.59              21.93      86.55           2.49
# 530    12.34        0.64  2.15              15.87     112.91           1.11
# 531    10.84        0.92  2.02              14.80      84.33           2.42
# 532    11.22        2.08  2.34              19.04      91.91           2.72
# 533    12.57        0.97  2.44              13.82      89.27           2.44
#
# ...

# %%
test_data = pd.read_csv("D:\Modules_UCD\EEEN40690\Final project\Wine_test.csv")
test_data = test_data.drop('id',axis=1)
test_data
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0      11.73        3.16  2.02              16.35     102.81           0.98
# 1      12.33       -0.06  1.47              13.12      73.68           1.41
# 2      11.84        2.20  2.43              24.50      86.33           1.43
# 3      13.03        3.31  1.99              17.22      83.23           2.15
# 4      12.16        0.76  2.13              16.08      78.92           1.73
# ..       ...         ...   ...                ...        ...            ...
# 173    11.81        1.71  1.88              19.46      85.82           2.49
# 174    13.57        0.81  2.21              12.90     115.47           2.29
# 175    10.93        1.08  2.22              18.68      71.51           1.40
# 176    12.95        1.34  2.06              15.01      95.92           2.31
# 177    14.20        1.61  2.39              13.83      92.72           2.36
#
# ...

# %%
X = training_data.drop('target', axis = 1)
y = training_data['target']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=0)

ss = StandardScaler()

X_train = ss.fit_transform(X_train)
X_test = ss.transform(X_test)

# %%
SVMlinear=SVC(kernel='linear', random_state = 0)
SVMpoly=SVC(kernel='poly', random_state=0)
SVMrbf=SVC(kernel='rbf', random_state=0)
SVMsigmoid=SVC(kernel='sigmoid', random_state=0)

# %%
SVMlinear.fit(X_train,y_train)
SVMpoly.fit(X_train,y_train)
SVMrbf.fit(X_train,y_train)
SVMsigmoid.fit(X_train,y_train)
# Out:
# SVC(kernel='sigmoid', random_state=0)

# %%
SVMlinear_pred = SVMlinear.predict(X_test)
SVMpoly_pred = SVMpoly.predict(X_test)
SVMrbf_pred = SVMrbf.predict(X_test)
SVMsigmoid_pred = SVMsigmoid.predict(X_test)

# %%
Accuracy_of_SVMlinear = accuracy_score(y_test, SVMlinear_pred)
print(Accuracy_of_SVMlinear)
Accuracy_of_SVMpoly = accuracy_score(y_test, SVMpoly_pred)
print(Accuracy_of_SVMpoly)
Accuracy_of_SVMrbf = accuracy_score(y_test, SVMrbf_pred)
print(Accuracy_of_SVMrbf)
Accuracy_of_SVMsigmoid = accuracy_score(y_test, SVMsigmoid_pred)
print(Accuracy_of_SVMsigmoid)
# Out:
# 0.9937888198757764
# 0.9875776397515528
# 0.9937888198757764
# 0.9627329192546584

# %%
test_data1 = ss.fit_transform(test_data)
SVMlinear_pred2 = SVMlinear.predict(test_data1)
SVMpoly_pred2 = SVMpoly.predict(test_data1)
SVMrbf_pred2 = SVMrbf.predict(test_data1)
SVMsigmoid_pred2 = SVMsigmoid.predict(test_data1)

# %%
SVMlinear_pred2
# Out:
# array([2, 1, 2, 0, 2, 1, 1, 1, 1, 0, 1, 1, 0, 1, 2, 1, 0, 2, 0, 1, 1, 1,
#        1, 0, 2, 2, 0, 1, 2, 0, 0, 2, 0, 0, 1, 0, 1, 1, 0, 2, 2, 0, 2, 2,
#        0, 1, 0, 2, 1, 2, 1, 0, 1, 0, 0, 2, 1, 2, 0, 0, 1, 0, 1, 0, 2, 2,
#        2, 0, 1, 1, 1, 1, 0, 2, 1, 1, 0, 0, 2, 0, 0, 1, 2, 1, 2, 1, 0, 1,
#        0, 1, 0, 1, 1, 1, 2, 1, 2, 2, 0, 1, 1, 1, 0, 0, 1, 1, 1, 2, 2, 0,
#        0, 0, 0, 0, 0, 2, 2, 1, 1, 2, 0, 0, 1, 2, 0, 2, 1, 1, 1, 0, 1, 1,
#        0, 2, 0, 1, 0, 1, 0, 0, 2, 1, 1, 1, 1, 2, 0, 2, 2, 1, 0, 0, 1, 1,
#        0, 0, 1, 0, 2, 1, 2, 0, 1, 2, 2, 1, 0, 1, 2, 2, 1, 0, 1, 1, 0, 1,
#        0, 0], dtype=int64)

# %%
print([SVMlinear_pred2[i]==SVMsigmoid_pred2[i] for i in range(len(SVMlinear_pred2))])
# Out:
# [True, True, True, True, True, True, False, True, True, False, True, True, True, True, True, True, False, True, True, True, True, True, True, True, True, True, True, True, True, False, True, True, True, True, True, True, True, True, False, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, False, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, False, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, 
# ...

# %%
training_data.corr()
plt.figure(figsize=(12, 8))
sns.heatmap(training_data.corr(), cmap='GnBu', linewidths=0.2, vmin=-1, vmax=1, annot=True, fmt = '0.2')
plt.show()

# %%
print("\n\nClassification Report for Linear SVM\n ",classification_report(y_test,SVMlinear_pred))


con_mat = confusion_matrix(y_test,SVMlinear_pred)
sns.heatmap(con_mat, annot=True, square=True)
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('Confusion Matrix')
# Out:
# Classification Report for Linear SVM
#                 precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99        54
#            1       0.99      1.00      0.99        68
#            2       1.00      1.00      1.00        39
#
#     accuracy                           0.99       161
#    macro avg       1.00      0.99      0.99       161
# weighted avg       0.99      0.99      0.99       161
# Text(0.5, 1.0, 'Confusion Matrix')

# %%
print("\n\nClassification Report for rbf SVM\n ",classification_report(y_test,SVMrbf_pred))


con_mat = confusion_matrix(y_test,SVMrbf_pred)
sns.heatmap(con_mat, annot=True, square=True)
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('Confusion Matrix')
# Out:
# Classification Report for rbf SVM
#                 precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        54
#            1       1.00      0.99      0.99        68
#            2       0.97      1.00      0.99        39
#
#     accuracy                           0.99       161
#    macro avg       0.99      1.00      0.99       161
# weighted avg       0.99      0.99      0.99       161
# Text(0.5, 1.0, 'Confusion Matrix')

# %%
print("\n\nClassification Report for poly SVM\n ",classification_report(y_test,SVMpoly_pred))


con_mat = confusion_matrix(y_test,SVMpoly_pred)
sns.heatmap(con_mat, annot=True, square=True)
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('Confusion Matrix')
# Out:
# Classification Report for poly SVM
#                 precision    recall  f1-score   support
#
#            0       1.00      0.96      0.98        54
#            1       0.97      1.00      0.99        68
#            2       1.00      1.00      1.00        39
#
#     accuracy                           0.99       161
#    macro avg       0.99      0.99      0.99       161
# weighted avg       0.99      0.99      0.99       161
# Text(0.5, 1.0, 'Confusion Matrix')

# %%
print("\n\nClassification Report for sigmoid SVM\n ",classification_report(y_test,SVMsigmoid_pred))


con_mat = confusion_matrix(y_test,SVMsigmoid_pred)
sns.heatmap(con_mat, annot=True, square=True)
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('Confusion Matrix')
# Out:
# Classification Report for sigmoid SVM
#                 precision    recall  f1-score   support
#
#            0       0.98      0.96      0.97        54
#            1       0.94      0.97      0.96        68
#            2       0.97      0.95      0.96        39
#
#     accuracy                           0.96       161
#    macro avg       0.97      0.96      0.96       161
# weighted avg       0.96      0.96      0.96       161
# Text(0.5, 1.0, 'Confusion Matrix')
